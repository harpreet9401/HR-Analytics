# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns',None)

# %%
general_data= pd.read_csv('general_data.csv')

# %%
manager_survey_data=pd.read_csv('manager_survey_data.csv')

# %%
employee_survey_data=pd.read_csv('employee_survey_data.csv')

# %%
in_time=pd.read_csv('in_time.csv')

# %%
out_time=pd.read_csv('out_time.csv')

# %%
data_dictionary=pd.read_excel('data_dictionary.xlsx')

# %%
general_data.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  JobLevel  \
# 0          2  Life Sciences              1           1  Female         1
# 1          1  Life Sciences              1           2  Female         1
# 2          4          Other              1           3    Male         4
# 3          5  Life Sciences              1           4    Male         3
# 4          1        Medical              1           5    Male         1
#
# ...

# %%
manager_survey_data.head()
# Out:
#    EmployeeID  JobInvolvement  PerformanceRating
# 0           1               3                  3
# 1           2               2                  4
# 2           3               3                  3
# 3           4               2                  3
# 4           5               3                  3

# %%
employee_survey_data.head()
# Out:
#    EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 0           1                      3.0              4.0              2.0
# 1           2                      3.0              2.0              4.0
# 2           3                      2.0              2.0              1.0
# 3           4                      4.0              4.0              3.0
# 4           5                      4.0              1.0              3.0

# %%
in_time.head()
# Out:
#    Unnamed: 0  2015-01-01           2015-01-02           2015-01-05  \
# 0           1         NaN  2015-01-02 09:43:45  2015-01-05 10:08:48
# 1           2         NaN  2015-01-02 10:15:44  2015-01-05 10:21:05
# 2           3         NaN  2015-01-02 10:17:41  2015-01-05 09:50:50
# 3           4         NaN  2015-01-02 10:05:06  2015-01-05 09:56:32
# 4           5         NaN  2015-01-02 10:28:17  2015-01-05 09:49:58
#
#             2015-01-06           2015-01-07           2015-01-08  \
# 0  2015-01-06 09:54:26  2015-01-07 09:34:31  2015-01-08 09:51:09
# 1                  NaN  2015-01-07 09:45:17  2015-01-08 10:09:04
# 2  2015-01-06 10:14:13  2015-01-07 09:47:27  2015-01-08 10:03:40
# 3  2015-01-06 10:11:07  2015-01-07 09:37:30  2015-01-08 10:02:08
# 4  2015-01-06 09:45:28  2015-01-07 09:49:37  2015-01-08 10:19:44
#
#             2015-01-09           2015-01-12           2015-01-13  2015-01-14  \
# 0  2015-01-09 10:09:25  2015-01-12 09:42:53  2015-01-13 10:13:06         NaN
# ...

# %%
out_time.head()
# Out:
#    Unnamed: 0  2015-01-01           2015-01-02           2015-01-05  \
# 0           1         NaN  2015-01-02 16:56:15  2015-01-05 17:20:11
# 1           2         NaN  2015-01-02 18:22:17  2015-01-05 17:48:22
# 2           3         NaN  2015-01-02 16:59:14  2015-01-05 17:06:46
# 3           4         NaN  2015-01-02 17:25:24  2015-01-05 17:14:03
# 4           5         NaN  2015-01-02 18:31:37  2015-01-05 17:49:15
#
#             2015-01-06           2015-01-07           2015-01-08  \
# 0  2015-01-06 17:19:05  2015-01-07 16:34:55  2015-01-08 17:08:32
# 1                  NaN  2015-01-07 17:09:06  2015-01-08 17:34:04
# 2  2015-01-06 16:38:32  2015-01-07 16:33:21  2015-01-08 17:24:22
# 3  2015-01-06 17:07:42  2015-01-07 16:32:40  2015-01-08 16:53:11
# 4  2015-01-06 17:26:25  2015-01-07 17:37:59  2015-01-08 17:59:28
#
#             2015-01-09           2015-01-12           2015-01-13  2015-01-14  \
# 0  2015-01-09 17:38:29  2015-01-12 16:58:39  2015-01-13 18:02:58         NaN
# ...

# %%
data_dictionary
# Out:
#                     Variable  \
# 0                        Age
# 1                  Attrition
# 2             BusinessTravel
# 3                 Department
# 4           DistanceFromHome
# 5                  Education
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10            EducationField
# 11             EmployeeCount
# 12            EmployeeNumber
# 13   EnvironmentSatisfaction
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                    Gender
# 18            JobInvolvement
# 19                       NaN
# 20                       NaN
# 21                       NaN
# 22                  JobLevel
# 23                   JobRole
# 24           JobSatisfaction
# 25                       NaN
# 26                       NaN
# 27                       NaN
# 28             MaritalStatus
# 29             MonthlyIncome
# 30        NumCompaniesWorked
# ...

# %%
in_time=in_time.dropna(how='all',axis=1)

# %%
out_time=out_time.dropna(how='all',axis=1)

# %%
in_time.fillna(0,inplace=True)
out_time.fillna(0,inplace=True)

# %%
in_time.columns[0]
# Out:
# 'Unnamed: 0'

# %%
in_time.drop(columns=['Unnamed: 0'],inplace=True)
out_time.drop(columns=['Unnamed: 0'],inplace=True)

# %%
in_time= in_time.apply(pd.to_datetime,errors='coerce')
out_time= out_time.apply(pd.to_datetime,errors='coerce')

# %%
in_time.shape
# Out:
# (4410, 249)

# %%
total_time=in_time.append(out_time)

# %%
total_time=total_time.diff(periods=4410)

# %%
total_time
# Out:
#           2015-01-02      2015-01-05      2015-01-06      2015-01-07  \
# 0                NaT             NaT             NaT             NaT
# 1                NaT             NaT             NaT             NaT
# 2                NaT             NaT             NaT             NaT
# 3                NaT             NaT             NaT             NaT
# 4                NaT             NaT             NaT             NaT
# ...              ...             ...             ...             ...
# 4405 0 days 08:07:05 0 days 08:50:27 0 days 08:23:58 0 days 08:50:42
# 4406 0 days 06:15:20 0 days 00:00:00 0 days 05:23:37 0 days 05:43:40
# 4407 0 days 07:16:34 0 days 07:35:07 0 days 07:38:29 0 days 07:59:10
# 4408 0 days 09:31:32 0 days 09:35:13 0 days 09:47:18 0 days 09:23:28
# 4409 0 days 06:50:10 0 days 07:16:48 0 days 06:43:40 0 days 06:50:32
#
#           2015-01-08      2015-01-09      2015-01-12      2015-01-13  \
# ...

# %%
total_time = total_time.iloc[4410:]

# %%
total_time
# Out:
#           2015-01-02      2015-01-05      2015-01-06      2015-01-07  \
# 0    0 days 07:12:30 0 days 07:11:23 0 days 07:24:39 0 days 07:00:24
# 1    0 days 08:06:33 0 days 07:27:17 0 days 00:00:00 0 days 07:23:49
# 2    0 days 06:41:33 0 days 07:15:56 0 days 06:24:19 0 days 06:45:54
# 3    0 days 07:20:18 0 days 07:17:31 0 days 06:56:35 0 days 06:55:10
# 4    0 days 08:03:20 0 days 07:59:17 0 days 07:40:57 0 days 07:48:22
# ...              ...             ...             ...             ...
# 4405 0 days 08:07:05 0 days 08:50:27 0 days 08:23:58 0 days 08:50:42
# 4406 0 days 06:15:20 0 days 00:00:00 0 days 05:23:37 0 days 05:43:40
# 4407 0 days 07:16:34 0 days 07:35:07 0 days 07:38:29 0 days 07:59:10
# 4408 0 days 09:31:32 0 days 09:35:13 0 days 09:47:18 0 days 09:23:28
# 4409 0 days 06:50:10 0 days 07:16:48 0 days 06:43:40 0 days 06:50:32
#
#           2015-01-08      2015-01-09      2015-01-12      2015-01-13  \
# ...

# %%
total_time['mean']=total_time.mean(axis=1)

# %%
total_time
# Out:
#           2015-01-02      2015-01-05      2015-01-06      2015-01-07  \
# 0    0 days 07:12:30 0 days 07:11:23 0 days 07:24:39 0 days 07:00:24
# 1    0 days 08:06:33 0 days 07:27:17 0 days 00:00:00 0 days 07:23:49
# 2    0 days 06:41:33 0 days 07:15:56 0 days 06:24:19 0 days 06:45:54
# 3    0 days 07:20:18 0 days 07:17:31 0 days 06:56:35 0 days 06:55:10
# 4    0 days 08:03:20 0 days 07:59:17 0 days 07:40:57 0 days 07:48:22
# ...              ...             ...             ...             ...
# 4405 0 days 08:07:05 0 days 08:50:27 0 days 08:23:58 0 days 08:50:42
# 4406 0 days 06:15:20 0 days 00:00:00 0 days 05:23:37 0 days 05:43:40
# 4407 0 days 07:16:34 0 days 07:35:07 0 days 07:38:29 0 days 07:59:10
# 4408 0 days 09:31:32 0 days 09:35:13 0 days 09:47:18 0 days 09:23:28
# 4409 0 days 06:50:10 0 days 07:16:48 0 days 06:43:40 0 days 06:50:32
#
#           2015-01-08      2015-01-09      2015-01-12      2015-01-13  \
# ...

# %%
total_time.iloc[0,0]
# Out:
# Timedelta('0 days 07:12:30')

# %%
total_time['mean'] = total_time['mean'].apply(lambda x : int(str(x).split(' ')[2].split(':')[0])  +  
            float(str(x).split(' ')[2].split(':')[1])/60 + float(str(x).split(' ')[2].split(':')[2])/3600)

# %%
total_time
# Out:
#           2015-01-02      2015-01-05      2015-01-06      2015-01-07  \
# 0    0 days 07:12:30 0 days 07:11:23 0 days 07:24:39 0 days 07:00:24
# 1    0 days 08:06:33 0 days 07:27:17 0 days 00:00:00 0 days 07:23:49
# 2    0 days 06:41:33 0 days 07:15:56 0 days 06:24:19 0 days 06:45:54
# 3    0 days 07:20:18 0 days 07:17:31 0 days 06:56:35 0 days 06:55:10
# 4    0 days 08:03:20 0 days 07:59:17 0 days 07:40:57 0 days 07:48:22
# ...              ...             ...             ...             ...
# 4405 0 days 08:07:05 0 days 08:50:27 0 days 08:23:58 0 days 08:50:42
# 4406 0 days 06:15:20 0 days 00:00:00 0 days 05:23:37 0 days 05:43:40
# 4407 0 days 07:16:34 0 days 07:35:07 0 days 07:38:29 0 days 07:59:10
# 4408 0 days 09:31:32 0 days 09:35:13 0 days 09:47:18 0 days 09:23:28
# 4409 0 days 06:50:10 0 days 07:16:48 0 days 06:43:40 0 days 06:50:32
#
#           2015-01-08      2015-01-09      2015-01-12      2015-01-13  \
# ...

# %%
total_time = total_time.reset_index()

# %%
total_time
# Out:
#       index      2015-01-02      2015-01-05      2015-01-06      2015-01-07  \
# 0         0 0 days 07:12:30 0 days 07:11:23 0 days 07:24:39 0 days 07:00:24
# 1         1 0 days 08:06:33 0 days 07:27:17 0 days 00:00:00 0 days 07:23:49
# 2         2 0 days 06:41:33 0 days 07:15:56 0 days 06:24:19 0 days 06:45:54
# 3         3 0 days 07:20:18 0 days 07:17:31 0 days 06:56:35 0 days 06:55:10
# 4         4 0 days 08:03:20 0 days 07:59:17 0 days 07:40:57 0 days 07:48:22
# ...     ...             ...             ...             ...             ...
# 4405   4405 0 days 08:07:05 0 days 08:50:27 0 days 08:23:58 0 days 08:50:42
# 4406   4406 0 days 06:15:20 0 days 00:00:00 0 days 05:23:37 0 days 05:43:40
# 4407   4407 0 days 07:16:34 0 days 07:35:07 0 days 07:38:29 0 days 07:59:10
# 4408   4408 0 days 09:31:32 0 days 09:35:13 0 days 09:47:18 0 days 09:23:28
# 4409   4409 0 days 06:50:10 0 days 07:16:48 0 days 06:43:40 0 days 06:50:32
#
# ...

# %%
total_time=total_time.rename(columns={'index':'EmployeeID'})

# %%
total_time=total_time[['EmployeeID','mean']]

# %%
total_time
# Out:
#       EmployeeID      mean
# 0              0  6.870229
# 1              1  7.315971
# 2              2  6.816081
# 3              3  6.789215
# 4              4  7.877561
# ...          ...       ...
# 4405        4405  8.316921
# 4406        4406  5.897197
# 4407        4407  7.149526
# 4408        4408  9.187612
# 4409        4409  6.511790
#
# [4410 rows x 2 columns]

# %%
total_time.EmployeeID = total_time.EmployeeID.apply(lambda x:x+1)

# %%
total_time
# Out:
#       EmployeeID      mean
# 0              1  6.870229
# 1              2  7.315971
# 2              3  6.816081
# 3              4  6.789215
# 4              5  7.877561
# ...          ...       ...
# 4405        4406  8.316921
# 4406        4407  5.897197
# 4407        4408  7.149526
# 4408        4409  9.187612
# 4409        4410  6.511790
#
# [4410 rows x 2 columns]

# %%
df = pd.merge(general_data,manager_survey_data,on='EmployeeID',how='inner')
df = pd.merge(df,employee_survey_data,on='EmployeeID',how='inner')

# %%
df = pd.merge(df,total_time,on='EmployeeID',how='inner')

# %%
df
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4410 entries, 0 to 4409
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4410 non-null   int64
#  1   Attrition                4410 non-null   object
#  2   BusinessTravel           4410 non-null   object
#  3   Department               4410 non-null   object
#  4   DistanceFromHome         4410 non-null   int64
#  5   Education                4410 non-null   int64
#  6   EducationField           4410 non-null   object
#  7   EmployeeCount            4410 non-null   int64
#  8   EmployeeID               4410 non-null   int64
#  9   Gender                   4410 non-null   object
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   object
#  12  MaritalStatus            4410 non-null   object
#  13  MonthlyIncome            4410 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeID                  0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# JobInvolvement              0
# PerformanceRating           0
# EnvironmentSatisfaction    25
# JobSatisfaction            20
# WorkLifeBalance            38
# mean                        0
# dtype: int64

# %%
df.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4410.000000       4410.000000  4410.000000         4410.0  4410.000000
# mean     36.923810          9.192517     2.912925            1.0  2205.500000
# std       9.133301          8.105026     1.023933            0.0  1273.201673
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1103.250000
# 50%      36.000000          7.000000     3.000000            1.0  2205.500000
# 75%      43.000000         14.000000     4.000000            1.0  3307.750000
# max      60.000000         29.000000     5.000000            1.0  4410.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4410.000000    4410.000000         4391.000000        4410.000000
# mean      2.063946   65029.312925            2.694830          15.209524
# ...

# %%
obj_cols=df.select_dtypes(include=['object']).columns

# %%
obj_cols
# Out:
# Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#        'JobRole', 'MaritalStatus', 'Over18'],
#       dtype='object')

# %%
for i in obj_cols:
    unique_values=len(df[i].value_counts())
    if unique_values==1:
        print(i)
# Out:
# Over18

# %%
df['Over18'].value_counts()
# Out:
# Y    4410
# Name: Over18, dtype: int64

# %%
df.drop(['EmployeeCount','StandardHours','Over18'],axis=1,inplace=True)

# %%
df
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeID  Gender  \
# 0                    6          2  Life Sciences           1  Female
# ...

# %%
df.isnull().sum()[df.isnull().sum()>0].index
# Out:
# Index(['NumCompaniesWorked', 'TotalWorkingYears', 'EnvironmentSatisfaction',
#        'JobSatisfaction', 'WorkLifeBalance'],
#       dtype='object')

# %%
plt.figure(figsize=(18,5))
sns.countplot(x='NumCompaniesWorked',data=df)
# Out:
# <AxesSubplot:xlabel='NumCompaniesWorked', ylabel='count'>

# %%
def makeplot(feature_name):
    for i in feature_name:
        plt.figure(figsize=(18,5))
        sns.countplot(x=i,data=df)

# %%
lst = ['NumCompaniesWorked','TotalWorkingYears','EnvironmentSatisfaction','JobSatisfaction','WorkLifeBalance']

# %%
makeplot(lst)

# %%
lst
# Out:
# ['NumCompaniesWorked',
#  'TotalWorkingYears',
#  'EnvironmentSatisfaction',
#  'JobSatisfaction',
#  'WorkLifeBalance']

# %%
df['WorkLifeBalance'].fillna(3.0,inplace=True)

# %%
df['JobSatisfaction'].fillna(4.0,inplace=True)

# %%
df['EnvironmentSatisfaction'].fillna(3.0,inplace=True)

# %%
df['TotalWorkingYears'].fillna(10.0,inplace=True)

# %%
df['NumCompaniesWorked'].fillna(1.0,inplace=True)

# %%
df_eda = df.copy()

# %%
def make_plots(feature_name):
    plt.figure(figsize=(18,7))
    sns.countplot(x=feature_name, hue='Attrition',data=df_eda)
    plt.xlabel(feature_name,fontsize=14)
    plt.ylabel('EmployeeCount',fontsize=18)
    plt.title('{} vs Attrition'.format(feature_name),fontsize=18)

# %%
make_plots('WorkLifeBalance')

# %%
make_plots('BusinessTravel')

# %%
make_plots('Department')

# %%
make_plots('Education')

# %%
make_plots('EducationField')

# %%
make_plots('Gender')

# %%
make_plots('JobLevel')

# %%
make_plots('MaritalStatus')

# %%
make_plots('StockOptionLevel')

# %%
make_plots('PerformanceRating')

# %%
df['Attrition'].value_counts()
# Out:
# No     3699
# Yes     711
# Name: Attrition, dtype: int64

# %%
df
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeID  Gender  \
# 0                    6          2  Life Sciences           1  Female
# ...

# %%
obj_cols
# Out:
# Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#        'JobRole', 'MaritalStatus', 'Over18'],
#       dtype='object')

# %%
one_hot_var = ['BusinessTravel', 'Department', 'EducationField', 'Gender',
       'JobRole', 'MaritalStatus']
for i in one_hot_var:
    x_t = pd.get_dummies(df[i],prefix=i,prefix_sep='_', drop_first=True)
    df = df.join(x_t)
    df.drop(i,axis=1,inplace=True)

# %%
df
# Out:
#       Age Attrition  DistanceFromHome  Education  EmployeeID  JobLevel  \
# 0      51        No                 6          2           1         1
# 1      31       Yes                10          1           2         1
# 2      32        No                17          4           3         4
# 3      38        No                 2          5           4         3
# 4      32        No                10          1           5         1
# ...   ...       ...               ...        ...         ...       ...
# 4405   42        No                 5          4        4406         1
# 4406   29        No                 2          4        4407         1
# 4407   25        No                25          2        4408         2
# 4408   42        No                18          2        4409         1
# 4409   40        No                28          3        4410         2
#
#       MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  StockOptionLevel  \
# ...

# %%
pd.get_dummies(df_eda['BusinessTravel'])
# Out:
#       Non-Travel  Travel_Frequently  Travel_Rarely
# 0              0                  0              1
# 1              0                  1              0
# 2              0                  1              0
# 3              1                  0              0
# 4              0                  0              1
# ...          ...                ...            ...
# 4405           0                  0              1
# 4406           0                  0              1
# 4407           0                  0              1
# 4408           0                  0              1
# 4409           0                  0              1
#
# [4410 rows x 3 columns]

# %%
df.Attrition=df.Attrition.apply(lambda x:1 if x=='Yes' else 0)

# %%
df
# Out:
#       Age  Attrition  DistanceFromHome  Education  EmployeeID  JobLevel  \
# 0      51          0                 6          2           1         1
# 1      31          1                10          1           2         1
# 2      32          0                17          4           3         4
# 3      38          0                 2          5           4         3
# 4      32          0                10          1           5         1
# ...   ...        ...               ...        ...         ...       ...
# 4405   42          0                 5          4        4406         1
# 4406   29          0                 2          4        4407         1
# 4407   25          0                25          2        4408         2
# 4408   42          0                18          2        4409         1
# 4409   40          0                28          3        4410         2
#
#       MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  StockOptionLevel  \
# ...

# %%
df.Attrition.value_counts()
# Out:
# 0    3699
# 1     711
# Name: Attrition, dtype: int64

# %%
pip install imblearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import SMOTE

# %%
x=df.drop('Attrition',axis=1)
y=df['Attrition']

# %%
smote = SMOTE(sampling_strategy='minority')
x_sm,y_sm = smote.fit_resample(x,y)

# %%
y_sm.value_counts()
# Out:
# 0    3699
# 1    3699
# Name: Attrition, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x_sm,y_sm,test_size=0.25,random_state =20)

# %%
x_train
# Out:
#       Age  DistanceFromHome  Education  EmployeeID  JobLevel  MonthlyIncome  \
# 5636   46                13          3         626         2          43070
# 89     47                 1          3          90         2          68340
# 1536   30                13          3        1537         4          41970
# 4585   23                 3          3        1682         2          38849
# 724    38                 7          3         725         2          76250
# ...   ...               ...        ...         ...       ...            ...
# 7386   28                 2          3         623         1          39455
# 7068   24                12          3        3071         1          75303
# 7391   32                16          4        3665         2          18644
# 4367   41                 1          3        4368         2          68830
# 2522   58                10          4        2523         1          29360
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train[x_train.columns] = scaler.fit_transform(x_train[x_train.columns])
x_test[x_test.columns] = scaler.fit_transform(x_test[x_test.columns])

# %%
df_corr = x_train.corr()

# %%
df_corr
# Out:
#                                         Age  DistanceFromHome  Education  \
# Age                                1.000000          0.031108  -0.003449
# DistanceFromHome                   0.031108          1.000000   0.015028
# Education                         -0.003449          0.015028   1.000000
# EmployeeID                         0.028457         -0.025679   0.016077
# JobLevel                           0.039571         -0.045419   0.088821
# MonthlyIncome                     -0.037675         -0.015152   0.036793
# NumCompaniesWorked                 0.313848         -0.029757   0.027303
# PercentSalaryHike                 -0.031327          0.052023  -0.019889
# StockOptionLevel                   0.033134          0.036416   0.018795
# TotalWorkingYears                  0.699191          0.017463   0.044533
# TrainingTimesLastYear             -0.061866          0.012757   0.055712
# YearsAtCompany                     0.389201          0.045548   0.040286
# ...

# %%
x_train.drop('Department_Sales',axis=1,inplace = True)
x_test.drop('Department_Sales',axis=1,inplace = True)

# %%
from sklearn.tree import DecisionTreeClassifier
ml = DecisionTreeClassifier()
ml.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = ml.predict(x_test)

# %%
y_pred
# Out:
# array([0, 1, 0, ..., 1, 1, 1])

# %%
y_test
# Out:
# 2582    0
# 6342    1
# 2745    0
# 5181    1
# 5060    1
#        ..
# 7385    1
# 1385    0
# 3428    0
# 5433    1
# 6916    1
# Name: Attrition, Length: 1850, dtype: int64

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.77      0.84       937
#            1       0.80      0.95      0.87       913
#
#     accuracy                           0.86      1850
#    macro avg       0.87      0.86      0.85      1850
# weighted avg       0.87      0.86      0.85      1850

# %%
from sklearn.metrics import accuracy_score,f1_score,precision_score, recall_score,confusion_matrix

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8551351351351352

# %%
f1_score(y_test,y_pred)
# Out:
# 0.8655967903711134

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[719, 218],
#        [ 50, 863]])

# %%
import pickle

# %%
with open('model pickle','wb') as f:
    pickle.dump(ml,f)

# %%
with open('model pickle','rb') as f:
    mp = pickle.load(f)

# %%
mp
# Out:
# DecisionTreeClassifier()

# %%
mp.predict(x_test)
# Out:
# array([0, 1, 0, ..., 1, 1, 1])

# %%
y_pred
# Out:
# array([0, 1, 0, ..., 1, 1, 1])
